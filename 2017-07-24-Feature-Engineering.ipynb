# %% [markdown]
# Feature Engineering
# ===
#
# Extract features from data
# 1. Calculated uncertainty
# 2. Extracted Weekends and Rush Hours
# 3. Save df as df-features.p

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
import seaborn as sns

sns.set_style('white')

df = pd.read_pickle('all-df.p')

# %%
df.shape
# Out:
# (893, 198)

# %%
df.head()
# Out:
#                      A-1-E-T-TF_Max  A-1-E-T-TF_Min  A-1-E-T-TF_RMS  \
# Time
# 2017-07-05 08:31:40        0.001316       -0.009395        0.002835
# 2017-07-05 08:41:40       -0.000422       -0.005926        0.003175
# 2017-07-05 08:51:40       -0.001178       -0.006039        0.003501
# 2017-07-05 09:01:40        0.000794       -0.008740        0.003870
# 2017-07-05 09:11:40        0.001489       -0.009407        0.004278
#
#                      A-10-E-TW-SF_Max  A-10-E-TW-SF_Min  A-10-E-TW-SF_RMS  \
# Time
# 2017-07-05 08:31:40          0.002083         -0.005025          0.001387
# 2017-07-05 08:41:40          0.000680         -0.003236          0.001452
# 2017-07-05 08:51:40          0.007270         -0.012717          0.001779
# 2017-07-05 09:01:40          0.002612         -0.004680          0.001660
# 2017-07-05 09:11:40          0.002304         -0.005447          0.001700
#
#                      A-2-E-T-TF_Max  A-2-E-T-TF_Min  A-2-E-T-TF_RMS  \
# Time
# 2017-07-05 08:31:40        0.006612       -0.008061        0.000974
# 2017-07-05 08:41:40        0.003827       -0.005288        0.001036
# 2017-07-05 08:51:40        0.006003       -0.007743        0.001243
# 2017-07-05 09:01:40        0.005343       -0.006587        0.001417
# 2017-07-05 09:11:40        0.006381       -0.009642        0.001682
#
#                      A-3-E-T-TF_Max       ...         T-10-E-TW-SF_Min  \
# Time                                      ...
# 2017-07-05 08:31:40        0.003837       ...                -0.017990
# 2017-07-05 08:41:40        0.002867       ...                -0.002721
# 2017-07-05 08:51:40        0.007602       ...                -0.245234
# 2017-07-05 09:01:40        0.005351       ...                -0.025048
# 2017-07-05 09:11:40        0.012568       ...                -0.008550
#
#                      T-10-E-TW-WB_Average  T-10-E-TW-WB_Max  T-10-E-TW-WB_Min  \
# Time
# 2017-07-05 08:31:40              0.128397          0.269324         -0.016863
# 2017-07-05 08:41:40              0.128355          0.194187          0.057718
# 2017-07-05 08:51:40              0.135325          0.587950         -0.379729
# 2017-07-05 09:01:40              0.148715          0.333798          0.007433
# 2017-07-05 09:11:40              0.158631          0.297861         -0.025897
#
#                      T-9-E-TW-SF_Average  T-9-E-TW-SF_Max  T-9-E-TW-SF_Min  \
# Time
# 2017-07-05 08:31:40             0.036715         0.166163        -0.090434
# 2017-07-05 08:41:40             0.036686         0.149379        -0.080413
# 2017-07-05 08:51:40             0.035531         0.161752        -0.063730
# 2017-07-05 09:01:40             0.037100         0.143737        -0.076553
# 2017-07-05 09:11:40             0.039205         0.198259        -0.106905
#
#                      T-9-E-TW-WB_Average  T-9-E-TW-WB_Max  T-9-E-TW-WB_Min
# Time
# 2017-07-05 08:31:40             0.033246         0.095981        -0.047871
# 2017-07-05 08:41:40             0.031260         0.079964        -0.018961
# 2017-07-05 08:51:40             0.029892         0.484039        -0.422958
# 2017-07-05 09:01:40             0.029019         0.105358        -0.047494
# 2017-07-05 09:11:40             0.030323         0.123140        -0.072853
#
# [5 rows x 198 columns]

# %% [markdown]
# ### New Columns: Uncertainty
# Format: Column_Name + _Uncertainty

# %% [markdown]
# #### Add columns for Uncertainty(fluctuation)

# %%
# Find all sensor names

import re
regex = '(.+)_'  # Find sensor names
matches = []
for col in df.columns:
    matches.append(re.findall(regex, col))

# remove duplicates

col_names = []

for i in matches:
    if i not in col_names:
        col_names.append(i)

# %%
# Assume Fluctuation = abs(Max) + abs(Min) (Note: not +- but a range instead)
# Need to ask/fix
# Bad coding :(

for i in range(len(col_names)):
    col_min = col_names[i][0] + '_Min'
    col_max = col_names[i][0] + '_Max'
    col_rms = col_names[i][0] + '_RMS'
    col_avg = col_names[i][0] + '_Average'
    try:
        df[col_names[i][0] + '_Uncertainty'] = abs(df[col_max]-df[col_rms]) + abs(df[col_min]-df[col_rms])
    except:
        df[col_names[i][0] + '_Uncertainty'] = abs(df[col_max]-df[col_avg]) + abs(df[col_min]-df[col_avg])

# %% [markdown]
# ### New Columns: Weekday
# Format: Weekday(1-7)

# %%
# 1 to 5 as Mon to Fri
# 6 and 7 as Sat and Sun
df['Weekday'] = df.index.weekday + 1

# %%
# Three rows with null date
# Why???

df[df['Weekday'].isnull()]
# Out:
#       A-1-E-T-TF_Max  A-1-E-T-TF_Min  A-1-E-T-TF_RMS  A-10-E-TW-SF_Max  \
# Time
# NaT              NaN             NaN             NaN               NaN
# NaT              NaN             NaN             NaN               NaN
# NaT              NaN             NaN             NaN               NaN
#
#       A-10-E-TW-SF_Min  A-10-E-TW-SF_RMS  A-2-E-T-TF_Max  A-2-E-T-TF_Min  \
# Time
# NaT                NaN               NaN             NaN             NaN
# NaT                NaN               NaN             NaN             NaN
# NaT                NaN               NaN             NaN             NaN
#
#       A-2-E-T-TF_RMS  A-3-E-T-TF_Max   ...     SG-9-E-R-A-H_Uncertainty  \
# Time                                   ...
# NaT              NaN             NaN   ...                     1.063232
# NaT              NaN             NaN   ...                     1.071960
# NaT              NaN             NaN   ...                     1.180420
#
#       SG-9-E-R-A-V_Uncertainty  SG-9-E-R-B-D_Uncertainty  \
# Time
# NaT                   1.098709                  1.023254
# NaT                   1.120407                  1.145233
# NaT                   1.103088                  1.293243
#
#       SG-9-E-R-B-H_Uncertainty  SG-9-E-R-B-V_Uncertainty  \
# Time
# NaT                   1.494293                  1.258751
# NaT                   1.594513                  1.071457
# NaT                   1.603180                  1.045326
#
#       T-10-E-TW-SF_Uncertainty  T-10-E-TW-WB_Uncertainty  \
# Time
# NaT                   0.023947                  0.068740
# NaT                   0.015447                  0.024495
# NaT                   0.006657                  0.007389
#
#       T-9-E-TW-SF_Uncertainty  T-9-E-TW-WB_Uncertainty  Weekday
# Time
# NaT                  0.020544                 0.027272      NaN
# NaT                  0.013647                 0.016427      NaN
# NaT                  0.005610                 0.006284      NaN
#
# [3 rows x 265 columns]

# %%
# Drop null date

df = df.dropna(subset=['Weekday'])

df['Weekday'] = df['Weekday'].astype(int)

# %% [markdown]
# ### New col: is_Weekend
# Format: is_Weekend (0 or 1)

# %%
def is_weekend(day):
    if day > 0 and day < 6:
        return 0
    else:
        return 1
    
df['is_Weekend'] = df['Weekday'].apply(is_weekend)

# %% [markdown]
# ### New col: is_Rush_Hour
# Format: is_Rush_Hour (0 or 1)
#
# [GeoStat](http://www.geostat.org/data/portsmouth-nh/commute)
# From 7 to 9am, estimate 5 to 7pm
#
# Rush Hour: not weekend and from 0700 to 0900 and 1700 to 1900

# %%
# Extract time(hour) from index
df['Hour'] = df.index.hour

# %%
len(df['Hour'].value_counts())
# Out:
# 24

# %%
def is_rush_hour(hour, is_weekend):
    
    def rush_hour(hour):
        if (hour > 6 and hour < 9) or (hour > 16 and hour < 19):
            return 1
        else:
            return 0
    
    if not is_weekend:
        if rush_hour(hour):
            return 1
        else:
            return 0
    else:
        return 0

# %%
df['is_Rush_Hour'] = df[['Hour', 'is_Weekend']].apply(lambda x: is_rush_hour(*x), axis=1)

# %%
df.corr()
# Out:
#                           A-1-E-T-TF_Max  A-1-E-T-TF_Min  A-1-E-T-TF_RMS  \
# A-1-E-T-TF_Max                  1.000000        0.545636       -0.834949
# A-1-E-T-TF_Min                  0.545636        1.000000       -0.893725
# A-1-E-T-TF_RMS                 -0.834949       -0.893725        1.000000
# A-10-E-TW-SF_Max               -0.074418       -0.429825        0.307412
# A-10-E-TW-SF_Min                0.173391        0.516866       -0.413626
# A-10-E-TW-SF_RMS               -0.281627       -0.382442        0.368516
# A-2-E-T-TF_Max                  0.016502       -0.034683        0.008372
# A-2-E-T-TF_Min                  0.168358        0.624000       -0.472847
# A-2-E-T-TF_RMS                 -0.784264       -0.889281        0.966396
# A-3-E-T-TF_Max                  0.036365       -0.018206       -0.011375
# A-3-E-T-TF_Min                  0.285189        0.709843       -0.583556
# A-3-E-T-TF_RMS                 -0.701566       -0.701494        0.836947
# A-3-W-T-TF_Max                  0.632832       -0.037943       -0.292082
# A-3-W-T-TF_Min                  0.376945        0.888635       -0.742077
# A-3-W-T-TF_RMS                 -0.818100       -0.850256        0.941387
# A-5-E-B-TF_Max                  0.016208       -0.026087        0.003900
# A-5-E-B-TF_Min                  0.170697        0.602487       -0.458353
# A-5-E-B-TF_RMS                 -0.560684       -0.643907        0.726506
# A-5-W-B-TF_Max                  0.499386       -0.211438       -0.121367
# A-5-W-B-TF_Min                  0.267021        0.835699       -0.654349
# A-5-W-B-TF_RMS                 -0.677372       -0.672112        0.773378
# A-6-E-T-TF_Max                  0.698534       -0.023199       -0.342296
# A-6-E-T-TF_Min                  0.342859        0.909777       -0.743524
# A-6-E-T-TF_RMS                 -0.793136       -0.854395        0.966992
# A-7-E-B-TF_Max                  0.220809       -0.583083        0.256266
# A-7-E-B-TF_Min                  0.024202        0.762903       -0.488012
# A-7-E-B-TF_RMS                 -0.685102       -0.717170        0.779924
# A-8-E-TW-SF_Max                -0.354399       -0.666408        0.594046
# A-8-E-TW-SF_Min                 0.357801        0.651026       -0.579761
# A-8-E-TW-SF_RMS                 0.166669        0.244162       -0.202284
# ...                                  ...             ...             ...
# SG-5-E-R-D-V_Uncertainty       -0.034214       -0.109535        0.088396
# SG-5-E-R-E-D_Uncertainty        0.155440       -0.550025        0.267796
# SG-5-E-R-E-H_Uncertainty        0.040797       -0.588513        0.347977
# SG-5-E-R-E-V_Uncertainty        0.007227       -0.527215        0.326670
# SG-8-E-R-A-D_Uncertainty       -0.135359       -0.338655        0.269362
# SG-8-E-R-A-H_Uncertainty       -0.108072       -0.283536        0.222935
# SG-8-E-R-A-V_Uncertainty       -0.146076       -0.402942        0.315343
# SG-8-E-R-B-D_Uncertainty       -0.142018       -0.360603        0.286687
# SG-8-E-R-B-H_Uncertainty       -0.032497       -0.178024        0.125083
# SG-8-E-R-B-V_Uncertainty       -0.156441       -0.414590        0.326804
# SG-8-W-R-A-D_Uncertainty       -0.106314       -0.227579        0.191203
# SG-8-W-R-A-H_Uncertainty       -0.037207       -0.103821        0.080645
# SG-8-W-R-A-V_Uncertainty       -0.098636       -0.209513        0.173685
# SG-8-W-R-B-D_Uncertainty       -0.169477       -0.309908        0.269285
# SG-8-W-R-B-H_Uncertainty       -0.086045       -0.333039        0.247434
# SG-8-W-R-B-V_Uncertainty       -0.154237       -0.367570        0.297627
# SG-9-E-R-A-D_Uncertainty       -0.071217       -0.162944        0.139750
# SG-9-E-R-A-H_Uncertainty       -0.079372       -0.116260        0.108248
# SG-9-E-R-A-V_Uncertainty       -0.096091       -0.182088        0.156335
# SG-9-E-R-B-D_Uncertainty       -0.068799       -0.112380        0.094908
# SG-9-E-R-B-H_Uncertainty       -0.076664       -0.137737        0.119532
# SG-9-E-R-B-V_Uncertainty       -0.071300       -0.185047        0.137180
# T-10-E-TW-SF_Uncertainty       -0.135837       -0.361024        0.294810
# T-10-E-TW-WB_Uncertainty       -0.137515       -0.454105        0.354998
# T-9-E-TW-SF_Uncertainty         0.033724       -0.588200        0.352779
# T-9-E-TW-WB_Uncertainty        -0.108867       -0.317079        0.248897
# Weekday                         0.388766        0.284697       -0.404865
# is_Weekend                      0.233237        0.217539       -0.280408
# Hour                           -0.141175       -0.074563        0.077490
# is_Rush_Hour                   -0.069037       -0.053028        0.043998
#
#                           A-10-E-TW-SF_Max  A-10-E-TW-SF_Min  \
# A-1-E-T-TF_Max                   -0.074418          0.173391
# A-1-E-T-TF_Min                   -0.429825          0.516866
# A-1-E-T-TF_RMS                    0.307412         -0.413626
# A-10-E-TW-SF_Max                  1.000000         -0.926125
# A-10-E-TW-SF_Min                 -0.926125          1.000000
# A-10-E-TW-SF_RMS                  0.296137         -0.518493
# A-2-E-T-TF_Max                    0.078469         -0.073077
# A-2-E-T-TF_Min                   -0.529707          0.546710
# A-2-E-T-TF_RMS                    0.366858         -0.454442
# A-3-E-T-TF_Max                    0.081990         -0.072642
# A-3-E-T-TF_Min                   -0.581965          0.616311
# A-3-E-T-TF_RMS                    0.311698         -0.363859
# A-3-W-T-TF_Max                    0.534107         -0.459647
# A-3-W-T-TF_Min                   -0.655476          0.692984
# A-3-W-T-TF_RMS                    0.320065         -0.400879
# A-5-E-B-TF_Max                    0.075194         -0.066873
# A-5-E-B-TF_Min                   -0.509515          0.545521
# A-5-E-B-TF_RMS                    0.235400         -0.377516
# A-5-W-B-TF_Max                    0.602661         -0.554251
# A-5-W-B-TF_Min                   -0.673544          0.692395
# A-5-W-B-TF_RMS                    0.307802         -0.320720
# A-6-E-T-TF_Max                    0.397361         -0.316636
# A-6-E-T-TF_Min                   -0.603798          0.658158
# A-6-E-T-TF_RMS                    0.319684         -0.410357
# A-7-E-B-TF_Max                    0.401581         -0.402189
# A-7-E-B-TF_Min                   -0.466560          0.497385
# A-7-E-B-TF_RMS                    0.263373         -0.347429
# A-8-E-TW-SF_Max                   0.597286         -0.609251
# A-8-E-TW-SF_Min                  -0.586974          0.579187
# A-8-E-TW-SF_RMS                  -0.165542          0.133770
# ...                                    ...               ...
# SG-5-E-R-D-V_Uncertainty          0.000094         -0.035197
# SG-5-E-R-E-D_Uncertainty          0.330176         -0.353968
# SG-5-E-R-E-H_Uncertainty          0.426500         -0.449678
# SG-5-E-R-E-V_Uncertainty          0.377258         -0.402655
# SG-8-E-R-A-D_Uncertainty          0.608620         -0.617484
# SG-8-E-R-A-H_Uncertainty          0.473632         -0.482154
# SG-8-E-R-A-V_Uncertainty          0.711407         -0.723526
# SG-8-E-R-B-D_Uncertainty          0.701225         -0.698266
# SG-8-E-R-B-H_Uncertainty          0.226238         -0.221765
# SG-8-E-R-B-V_Uncertainty          0.743631         -0.745233
# SG-8-W-R-A-D_Uncertainty          0.413327         -0.418204
# SG-8-W-R-A-H_Uncertainty          0.159128         -0.161061
# SG-8-W-R-A-V_Uncertainty          0.366522         -0.370727
# SG-8-W-R-B-D_Uncertainty          0.563253         -0.552691
# SG-8-W-R-B-H_Uncertainty          0.431858         -0.424247
# SG-8-W-R-B-V_Uncertainty          0.687427         -0.698633
# SG-9-E-R-A-D_Uncertainty          0.010080         -0.095419
# SG-9-E-R-A-H_Uncertainty          0.336112         -0.324714
# SG-9-E-R-A-V_Uncertainty          0.491170         -0.468191
# SG-9-E-R-B-D_Uncertainty          0.506043         -0.510187
# SG-9-E-R-B-H_Uncertainty          0.395813         -0.391274
# SG-9-E-R-B-V_Uncertainty          0.525943         -0.511328
# T-10-E-TW-SF_Uncertainty          0.910602         -0.898724
# T-10-E-TW-WB_Uncertainty          0.978678         -0.973153
# T-9-E-TW-SF_Uncertainty           0.738767         -0.752932
# T-9-E-TW-WB_Uncertainty           0.911597         -0.860502
# Weekday                          -0.026260          0.131629
# is_Weekend                       -0.067291          0.154730
# Hour                              0.059626         -0.027216
# is_Rush_Hour                      0.047744         -0.081305
#
#                           A-10-E-TW-SF_RMS  A-2-E-T-TF_Max  A-2-E-T-TF_Min  \
# A-1-E-T-TF_Max                   -0.281627        0.016502        0.168358
# A-1-E-T-TF_Min                   -0.382442       -0.034683        0.624000
# A-1-E-T-TF_RMS                    0.368516        0.008372       -0.472847
# A-10-E-TW-SF_Max                  0.296137        0.078469       -0.529707
# A-10-E-TW-SF_Min                 -0.518493       -0.073077        0.546710
# A-10-E-TW-SF_RMS                  1.000000        0.046857       -0.280443
# A-2-E-T-TF_Max                    0.046857        1.000000       -0.718631
# A-2-E-T-TF_Min                   -0.280443       -0.718631        1.000000
# A-2-E-T-TF_RMS                    0.338827        0.184855       -0.620201
# A-3-E-T-TF_Max                    0.037114        0.998947       -0.711708
# A-3-E-T-TF_Min                   -0.366849       -0.621177        0.956614
# A-3-E-T-TF_RMS                    0.150652        0.170973       -0.516312
# A-3-W-T-TF_Max                    0.092797        0.053455       -0.318098
# A-3-W-T-TF_Min                   -0.371612       -0.037970        0.669941
# A-3-W-T-TF_RMS                    0.314475       -0.000652       -0.449209
# A-5-E-B-TF_Max                    0.035495        0.999133       -0.711154
# A-5-E-B-TF_Min                   -0.343918       -0.726196        0.963386
# A-5-E-B-TF_RMS                    0.485107        0.183848       -0.472351
# A-5-W-B-TF_Max                    0.193081        0.059110       -0.423943
# A-5-W-B-TF_Min                   -0.321301       -0.042183        0.668342
# A-5-W-B-TF_RMS                    0.055676       -0.026619       -0.354450
# A-6-E-T-TF_Max                   -0.010419        0.047949       -0.303450
# A-6-E-T-TF_Min                   -0.400701       -0.045706        0.696127
# A-6-E-T-TF_RMS                    0.300164        0.001882       -0.469617
# A-7-E-B-TF_Max                    0.146255        0.037792       -0.523088
# A-7-E-B-TF_Min                   -0.256184       -0.041750        0.607050
# A-7-E-B-TF_RMS                    0.329120        0.011600       -0.388331
# A-8-E-TW-SF_Max                   0.283975        0.092642       -0.538957
# A-8-E-TW-SF_Min                  -0.214742       -0.095643        0.526158
# A-8-E-TW-SF_RMS                   0.042680       -0.035797        0.162085
# ...                                    ...             ...             ...
# SG-5-E-R-D-V_Uncertainty          0.150389        0.000439       -0.080455
# SG-5-E-R-E-D_Uncertainty          0.164798        0.055773       -0.475876
# SG-5-E-R-E-H_Uncertainty          0.208627        0.079290       -0.512276
# SG-5-E-R-E-V_Uncertainty          0.163869        0.091625       -0.464464
# SG-8-E-R-A-D_Uncertainty          0.274100        0.067740       -0.361172
# SG-8-E-R-A-H_Uncertainty          0.223677        0.043206       -0.285852
# SG-8-E-R-A-V_Uncertainty          0.336541        0.057367       -0.412663
# SG-8-E-R-B-D_Uncertainty          0.291978        0.074766       -0.400802
# SG-8-E-R-B-H_Uncertainty          0.093666        0.090022       -0.212913
# SG-8-E-R-B-V_Uncertainty          0.317866        0.063984       -0.429203
# SG-8-W-R-A-D_Uncertainty          0.177591        0.064198       -0.251327
# SG-8-W-R-A-H_Uncertainty          0.072702        0.039902       -0.114733
# SG-8-W-R-A-V_Uncertainty          0.156202        0.034706       -0.211697
# SG-8-W-R-B-D_Uncertainty          0.229861        0.065919       -0.331433
# SG-8-W-R-B-H_Uncertainty          0.168066        0.069893       -0.335521
# SG-8-W-R-B-V_Uncertainty          0.304340        0.066277       -0.389266
# SG-9-E-R-A-D_Uncertainty          0.289144        0.080366       -0.147302
# SG-9-E-R-A-H_Uncertainty          0.134288        0.045375       -0.157572
# SG-9-E-R-A-V_Uncertainty          0.196405        0.028733       -0.222613
# SG-9-E-R-B-D_Uncertainty          0.225850        0.172573       -0.274851
# SG-9-E-R-B-H_Uncertainty          0.147329        0.032900       -0.174246
# SG-9-E-R-B-V_Uncertainty          0.233157        0.197990       -0.344537
# T-10-E-TW-SF_Uncertainty          0.341977        0.093760       -0.467613
# T-10-E-TW-WB_Uncertainty          0.409918        0.075304       -0.529589
# T-9-E-TW-SF_Uncertainty           0.326516        0.084384       -0.631235
# T-9-E-TW-WB_Uncertainty           0.338112        0.078475       -0.444561
# Weekday                          -0.326247        0.058345        0.094134
# is_Weekend                       -0.293140        0.047459        0.090004
# Hour                             -0.049313        0.008675       -0.042197
# is_Rush_Hour                      0.092779       -0.009621       -0.014767
#
#                           A-2-E-T-TF_RMS  A-3-E-T-TF_Max      ...       \
# A-1-E-T-TF_Max                 -0.784264        0.036365      ...
# A-1-E-T-TF_Min                 -0.889281       -0.018206      ...
# A-1-E-T-TF_RMS                  0.966396       -0.011375      ...
# A-10-E-TW-SF_Max                0.366858        0.081990      ...
# A-10-E-TW-SF_Min               -0.454442       -0.072642      ...
# A-10-E-TW-SF_RMS                0.338827        0.037114      ...
# A-2-E-T-TF_Max                  0.184855        0.998947      ...
# A-2-E-T-TF_Min                 -0.620201       -0.711708      ...
# A-2-E-T-TF_RMS                  1.000000        0.166716      ...
# A-3-E-T-TF_Max                  0.166716        1.000000      ...
# A-3-E-T-TF_Min                 -0.705841       -0.616694      ...
# A-3-E-T-TF_RMS                  0.903094        0.159521      ...
# A-3-W-T-TF_Max                 -0.240878        0.073416      ...
# A-3-W-T-TF_Min                 -0.772185       -0.030905      ...
# A-3-W-T-TF_RMS                  0.938764       -0.021703      ...
# A-5-E-B-TF_Max                  0.181720        0.999093      ...
# A-5-E-B-TF_Min                 -0.592617       -0.724286      ...
# A-5-E-B-TF_RMS                  0.708124        0.174631      ...
# A-5-W-B-TF_Max                 -0.067808        0.074419      ...
# A-5-W-B-TF_Min                 -0.689462       -0.036190      ...
# A-5-W-B-TF_RMS                  0.794048       -0.042819      ...
# A-6-E-T-TF_Max                 -0.286824        0.061817      ...
# A-6-E-T-TF_Min                 -0.767175       -0.034562      ...
# A-6-E-T-TF_RMS                  0.968940       -0.015166      ...
# A-7-E-B-TF_Max                  0.285947        0.042153      ...
# A-7-E-B-TF_Min                 -0.519971       -0.038310      ...
# A-7-E-B-TF_RMS                  0.786740       -0.008158      ...
# A-8-E-TW-SF_Max                 0.616126        0.085112      ...
# A-8-E-TW-SF_Min                -0.606617       -0.088531      ...
# A-8-E-TW-SF_RMS                -0.211168       -0.033991      ...
# ...                                  ...             ...      ...
# SG-5-E-R-D-V_Uncertainty        0.079491       -0.001195      ...
# SG-5-E-R-E-D_Uncertainty        0.303495        0.055360      ...
# SG-5-E-R-E-H_Uncertainty        0.387167        0.078034      ...
# SG-5-E-R-E-V_Uncertainty        0.368723        0.090565      ...
# SG-8-E-R-A-D_Uncertainty        0.308985        0.065625      ...
# SG-8-E-R-A-H_Uncertainty        0.251395        0.041487      ...
# SG-8-E-R-A-V_Uncertainty        0.351417        0.056328      ...
# SG-8-E-R-B-D_Uncertainty        0.331761        0.073302      ...
# SG-8-E-R-B-H_Uncertainty        0.155543        0.089509      ...
# SG-8-E-R-B-V_Uncertainty        0.372185        0.061813      ...
# SG-8-W-R-A-D_Uncertainty        0.226017        0.063331      ...
# SG-8-W-R-A-H_Uncertainty        0.099673        0.039843      ...
# SG-8-W-R-A-V_Uncertainty        0.200304        0.033673      ...
# SG-8-W-R-B-D_Uncertainty        0.310624        0.064116      ...
# SG-8-W-R-B-H_Uncertainty        0.283987        0.068906      ...
# SG-8-W-R-B-V_Uncertainty        0.341244        0.065073      ...
# SG-9-E-R-A-D_Uncertainty        0.126011        0.078374      ...
# SG-9-E-R-A-H_Uncertainty        0.132074        0.045343      ...
# SG-9-E-R-A-V_Uncertainty        0.185865        0.028816      ...
# SG-9-E-R-B-D_Uncertainty        0.147692        0.174594      ...
# SG-9-E-R-B-H_Uncertainty        0.146181        0.033914      ...
# SG-9-E-R-B-V_Uncertainty        0.199402        0.198456      ...
# T-10-E-TW-SF_Uncertainty        0.346202        0.093566      ...
# T-10-E-TW-WB_Uncertainty        0.406040        0.077413      ...
# T-9-E-TW-SF_Uncertainty         0.404848        0.075807      ...
# T-9-E-TW-WB_Uncertainty         0.298051        0.078349      ...
# Weekday                        -0.381047        0.068088      ...
# is_Weekend                     -0.278724        0.054131      ...
# Hour                            0.110114        0.002197      ...
# is_Rush_Hour                    0.044327       -0.012540      ...
#
#                           SG-9-E-R-B-H_Uncertainty  SG-9-E-R-B-V_Uncertainty  \
# A-1-E-T-TF_Max                           -0.076664                 -0.071300
# A-1-E-T-TF_Min                           -0.137737                 -0.185047
# A-1-E-T-TF_RMS                            0.119532                  0.137180
# A-10-E-TW-SF_Max                          0.395813                  0.525943
# A-10-E-TW-SF_Min                         -0.391274                 -0.511328
# A-10-E-TW-SF_RMS                          0.147329                  0.233157
# A-2-E-T-TF_Max                            0.032900                  0.197990
# A-2-E-T-TF_Min                           -0.174246                 -0.344537
# A-2-E-T-TF_RMS                            0.146181                  0.199402
# A-3-E-T-TF_Max                            0.033914                  0.198456
# A-3-E-T-TF_Min                           -0.199433                 -0.366208
# A-3-E-T-TF_RMS                            0.120170                  0.155731
# A-3-W-T-TF_Max                            0.141152                  0.230834
# A-3-W-T-TF_Min                           -0.213209                 -0.293163
# A-3-W-T-TF_RMS                            0.132686                  0.159067
# A-5-E-B-TF_Max                            0.031912                  0.195904
# A-5-E-B-TF_Min                           -0.176874                 -0.348974
# A-5-E-B-TF_RMS                            0.075110                  0.116643
# A-5-W-B-TF_Max                            0.168311                  0.257049
# A-5-W-B-TF_Min                           -0.213096                 -0.300394
# A-5-W-B-TF_RMS                            0.123524                  0.144090
# A-6-E-T-TF_Max                            0.077649                  0.148649
# A-6-E-T-TF_Min                           -0.188734                 -0.262080
# A-6-E-T-TF_RMS                            0.120805                  0.132125
# A-7-E-B-TF_Max                            0.076208                  0.125588
# A-7-E-B-TF_Min                           -0.129213                 -0.185214
# A-7-E-B-TF_RMS                            0.114179                  0.171294
# A-8-E-TW-SF_Max                           0.211427                  0.338655
# A-8-E-TW-SF_Min                          -0.488190                 -0.531034
# A-8-E-TW-SF_RMS                          -0.133493                 -0.166268
# ...                                            ...                       ...
# SG-5-E-R-D-V_Uncertainty                 -0.001524                 -0.005172
# SG-5-E-R-E-D_Uncertainty                  0.335172                  0.321065
# SG-5-E-R-E-H_Uncertainty                  0.489071                  0.462185
# SG-5-E-R-E-V_Uncertainty                  0.628558                  0.546657
# SG-8-E-R-A-D_Uncertainty                  0.872024                  0.828014
# SG-8-E-R-A-H_Uncertainty                  0.909902                  0.819509
# SG-8-E-R-A-V_Uncertainty                  0.804410                  0.803214
# SG-8-E-R-B-D_Uncertainty                  0.817283                  0.812479
# SG-8-E-R-B-H_Uncertainty                  0.874465                  0.729607
# SG-8-E-R-B-V_Uncertainty                  0.760599                  0.788098
# SG-8-W-R-A-D_Uncertainty                  0.931466                  0.822256
# SG-8-W-R-A-H_Uncertainty                  0.886269                  0.712755
# SG-8-W-R-A-V_Uncertainty                  0.932165                  0.800835
# SG-8-W-R-B-D_Uncertainty                  0.872416                  0.817535
# SG-8-W-R-B-H_Uncertainty                  0.868931                  0.771992
# SG-8-W-R-B-V_Uncertainty                  0.834288                  0.815227
# SG-9-E-R-A-D_Uncertainty                  0.235612                  0.168330
# SG-9-E-R-A-H_Uncertainty                  0.968630                  0.783021
# SG-9-E-R-A-V_Uncertainty                  0.943573                  0.846914
# SG-9-E-R-B-D_Uncertainty                  0.724931                  0.879328
# SG-9-E-R-B-H_Uncertainty                  1.000000                  0.797023
# SG-9-E-R-B-V_Uncertainty                  0.797023                  1.000000
# T-10-E-TW-SF_Uncertainty                  0.467971                  0.567524
# T-10-E-TW-WB_Uncertainty                  0.430648                  0.554092
# T-9-E-TW-SF_Uncertainty                   0.272899                  0.375723
# T-9-E-TW-WB_Uncertainty                   0.449464                  0.557295
# Weekday                                  -0.027319                  0.014824
# is_Weekend                               -0.065561                 -0.028257
# Hour                                     -0.005475                  0.066845
# is_Rush_Hour                              0.166358                  0.154757
#
#                           T-10-E-TW-SF_Uncertainty  T-10-E-TW-WB_Uncertainty  \
# A-1-E-T-TF_Max                           -0.135837                 -0.137515
# A-1-E-T-TF_Min                           -0.361024                 -0.454105
# A-1-E-T-TF_RMS                            0.294810                  0.354998
# A-10-E-TW-SF_Max                          0.910602                  0.978678
# A-10-E-TW-SF_Min                         -0.898724                 -0.973153
# A-10-E-TW-SF_RMS                          0.341977                  0.409918
# A-2-E-T-TF_Max                            0.093760                  0.075304
# A-2-E-T-TF_Min                           -0.467613                 -0.529589
# A-2-E-T-TF_RMS                            0.346202                  0.406040
# A-3-E-T-TF_Max                            0.093566                  0.077413
# A-3-E-T-TF_Min                           -0.511469                 -0.594706
# A-3-E-T-TF_RMS                            0.295807                  0.339479
# A-3-W-T-TF_Max                            0.397320                  0.490662
# A-3-W-T-TF_Min                           -0.547411                 -0.667216
# A-3-W-T-TF_RMS                            0.307290                  0.359739
# A-5-E-B-TF_Max                            0.088471                  0.071374
# A-5-E-B-TF_Min                           -0.446740                 -0.520129
# A-5-E-B-TF_RMS                            0.244611                  0.299764
# A-5-W-B-TF_Max                            0.460498                  0.568903
# A-5-W-B-TF_Min                           -0.555650                 -0.674220
# A-5-W-B-TF_RMS                            0.290348                  0.318841
# A-6-E-T-TF_Max                            0.280319                  0.341504
# A-6-E-T-TF_Min                           -0.512131                 -0.617141
# A-6-E-T-TF_RMS                            0.299875                  0.361834
# A-7-E-B-TF_Max                            0.267965                  0.368817
# A-7-E-B-TF_Min                           -0.349170                 -0.454203
# A-7-E-B-TF_RMS                            0.255503                  0.302916
# A-8-E-TW-SF_Max                           0.571134                  0.600879
# A-8-E-TW-SF_Min                          -0.546058                 -0.580430
# A-8-E-TW-SF_RMS                          -0.156324                 -0.146093
# ...                                            ...                       ...
# SG-5-E-R-D-V_Uncertainty                  0.002995                  0.014274
# SG-5-E-R-E-D_Uncertainty                  0.225416                  0.325026
# SG-5-E-R-E-H_Uncertainty                  0.336903                  0.430987
# SG-5-E-R-E-V_Uncertainty                  0.312047                  0.382944
# SG-8-E-R-A-D_Uncertainty                  0.642828                  0.638104
# SG-8-E-R-A-H_Uncertainty                  0.492502                  0.500009
# SG-8-E-R-A-V_Uncertainty                  0.724301                  0.734522
# SG-8-E-R-B-D_Uncertainty                  0.719237                  0.721356
# SG-8-E-R-B-H_Uncertainty                  0.222553                  0.236953
# SG-8-E-R-B-V_Uncertainty                  0.750413                  0.759408
# SG-8-W-R-A-D_Uncertainty                  0.435985                  0.434540
# SG-8-W-R-A-H_Uncertainty                  0.163211                  0.166301
# SG-8-W-R-A-V_Uncertainty                  0.389388                  0.387590
# SG-8-W-R-B-D_Uncertainty                  0.602166                  0.588111
# SG-8-W-R-B-H_Uncertainty                  0.420361                  0.448599
# SG-8-W-R-B-V_Uncertainty                  0.722919                  0.714025
# SG-9-E-R-A-D_Uncertainty                  0.007418                  0.055311
# SG-9-E-R-A-H_Uncertainty                  0.390738                  0.365883
# SG-9-E-R-A-V_Uncertainty                  0.528834                  0.517202
# SG-9-E-R-B-D_Uncertainty                  0.598100                  0.539832
# SG-9-E-R-B-H_Uncertainty                  0.467971                  0.430648
# SG-9-E-R-B-V_Uncertainty                  0.567524                  0.554092
# T-10-E-TW-SF_Uncertainty                  1.000000                  0.922922
# T-10-E-TW-WB_Uncertainty                  0.922922                  1.000000
# T-9-E-TW-SF_Uncertainty                   0.671256                  0.718035
# T-9-E-TW-WB_Uncertainty                   0.956628                  0.911491
# Weekday                                  -0.049783                 -0.080170
# is_Weekend                               -0.078462                 -0.117237
# Hour                                      0.045003                  0.049788
# is_Rush_Hour                              0.088694                  0.075684
#
#                           T-9-E-TW-SF_Uncertainty  T-9-E-TW-WB_Uncertainty  \
# A-1-E-T-TF_Max                           0.033724                -0.108867
# A-1-E-T-TF_Min                          -0.588200                -0.317079
# A-1-E-T-TF_RMS                           0.352779                 0.248897
# A-10-E-TW-SF_Max                         0.738767                 0.911597
# A-10-E-TW-SF_Min                        -0.752932                -0.860502
# A-10-E-TW-SF_RMS                         0.326516                 0.338112
# A-2-E-T-TF_Max                           0.084384                 0.078475
# A-2-E-T-TF_Min                          -0.631235                -0.444561
# A-2-E-T-TF_RMS                           0.404848                 0.298051
# A-3-E-T-TF_Max                           0.075807                 0.078349
# A-3-E-T-TF_Min                          -0.609915                -0.486392
# A-3-E-T-TF_RMS                           0.289400                 0.247192
# A-3-W-T-TF_Max                           0.542861                 0.412723
# A-3-W-T-TF_Min                          -0.702438                -0.517813
# A-3-W-T-TF_RMS                           0.330334                 0.270964
# A-5-E-B-TF_Max                           0.069543                 0.072918
# A-5-E-B-TF_Min                          -0.568774                -0.419352
# A-5-E-B-TF_RMS                           0.296611                 0.200847
# A-5-W-B-TF_Max                           0.649277                 0.469389
# A-5-W-B-TF_Min                          -0.737348                -0.529811
# A-5-W-B-TF_RMS                           0.268715                 0.259306
# A-6-E-T-TF_Max                           0.592667                 0.306709
# A-6-E-T-TF_Min                          -0.780245                -0.485125
# A-6-E-T-TF_RMS                           0.355315                 0.251889
# A-7-E-B-TF_Max                           0.648137                 0.246891
# A-7-E-B-TF_Min                          -0.704369                -0.322497
# A-7-E-B-TF_RMS                           0.291795                 0.229592
# A-8-E-TW-SF_Max                          0.616870                 0.520609
# A-8-E-TW-SF_Min                         -0.583702                -0.499948
# A-8-E-TW-SF_RMS                         -0.134237                -0.144225
# ...                                           ...                      ...
# SG-5-E-R-D-V_Uncertainty                 0.069455                -0.001830
# SG-5-E-R-E-D_Uncertainty                 0.612209                 0.179362
# SG-5-E-R-E-H_Uncertainty                 0.622749                 0.295817
# SG-5-E-R-E-V_Uncertainty                 0.558887                 0.257646
# SG-8-E-R-A-D_Uncertainty                 0.512892                 0.613553
# SG-8-E-R-A-H_Uncertainty                 0.407140                 0.465088
# SG-8-E-R-A-V_Uncertainty                 0.586665                 0.690862
# SG-8-E-R-B-D_Uncertainty                 0.553740                 0.697177
# SG-8-E-R-B-H_Uncertainty                 0.236940                 0.205937
# SG-8-E-R-B-V_Uncertainty                 0.603682                 0.720303
# SG-8-W-R-A-D_Uncertainty                 0.335097                 0.402425
# SG-8-W-R-A-H_Uncertainty                 0.136380                 0.143459
# SG-8-W-R-A-V_Uncertainty                 0.301360                 0.363018
# SG-8-W-R-B-D_Uncertainty                 0.441548                 0.585909
# SG-8-W-R-B-H_Uncertainty                 0.432248                 0.399641
# SG-8-W-R-B-V_Uncertainty                 0.547367                 0.687684
# SG-9-E-R-A-D_Uncertainty                 0.095219                 0.007713
# SG-9-E-R-A-H_Uncertainty                 0.228256                 0.390396
# SG-9-E-R-A-V_Uncertainty                 0.340162                 0.535300
# SG-9-E-R-B-D_Uncertainty                 0.323071                 0.574403
# SG-9-E-R-B-H_Uncertainty                 0.272899                 0.449464
# SG-9-E-R-B-V_Uncertainty                 0.375723                 0.557295
# T-10-E-TW-SF_Uncertainty                 0.671256                 0.956628
# T-10-E-TW-WB_Uncertainty                 0.718035                 0.911491
# T-9-E-TW-SF_Uncertainty                  1.000000                 0.656924
# T-9-E-TW-WB_Uncertainty                  0.656924                 1.000000
# Weekday                                 -0.069746                -0.036117
# is_Weekend                              -0.139241                -0.064626
# Hour                                     0.008580                 0.054604
# is_Rush_Hour                             0.097314                 0.070984
#
#                            Weekday  is_Weekend      Hour  is_Rush_Hour
# A-1-E-T-TF_Max            0.388766    0.233237 -0.141175     -0.069037
# A-1-E-T-TF_Min            0.284697    0.217539 -0.074563     -0.053028
# A-1-E-T-TF_RMS           -0.404865   -0.280408  0.077490      0.043998
# A-10-E-TW-SF_Max         -0.026260   -0.067291  0.059626      0.047744
# A-10-E-TW-SF_Min          0.131629    0.154730 -0.027216     -0.081305
# A-10-E-TW-SF_RMS         -0.326247   -0.293140 -0.049313      0.092779
# A-2-E-T-TF_Max            0.058345    0.047459  0.008675     -0.009621
# A-2-E-T-TF_Min            0.094134    0.090004 -0.042197     -0.014767
# A-2-E-T-TF_RMS           -0.381047   -0.278724  0.110114      0.044327
# A-3-E-T-TF_Max            0.068088    0.054131  0.002197     -0.012540
# A-3-E-T-TF_Min            0.142047    0.135103 -0.070531     -0.041623
# A-3-E-T-TF_RMS           -0.380955   -0.309661  0.062295      0.041629
# A-3-W-T-TF_Max            0.238610    0.097995 -0.122900     -0.028590
# A-3-W-T-TF_Min            0.221305    0.202855 -0.116377     -0.068197
# A-3-W-T-TF_RMS           -0.382224   -0.267913  0.209073      0.093715
# A-5-E-B-TF_Max            0.060100    0.050436  0.013050     -0.009936
# A-5-E-B-TF_Min            0.092812    0.101483  0.003177     -0.031128
# A-5-E-B-TF_RMS           -0.332426   -0.299290 -0.146809     -0.075057
# A-5-W-B-TF_Max            0.166125    0.047647 -0.108317     -0.046661
# A-5-W-B-TF_Min            0.173163    0.170126 -0.108104     -0.096411
# A-5-W-B-TF_RMS           -0.331621   -0.249395  0.225408      0.158645
# A-6-E-T-TF_Max            0.244892    0.117628 -0.082618      0.002603
# A-6-E-T-TF_Min            0.228301    0.199021 -0.053398     -0.050372
# A-6-E-T-TF_RMS           -0.411226   -0.305819  0.087272      0.006740
# A-7-E-B-TF_Max            0.022279   -0.033453 -0.043370     -0.026976
# A-7-E-B-TF_Min            0.112325    0.136280 -0.020906     -0.069262
# A-7-E-B-TF_RMS           -0.397268   -0.309662  0.188446      0.242421
# A-8-E-TW-SF_Max          -0.234675   -0.234375  0.062887      0.082048
# A-8-E-TW-SF_Min           0.220700    0.223049 -0.070186     -0.168846
# A-8-E-TW-SF_RMS           0.063308    0.018374 -0.043230     -0.323271
# ...                            ...         ...       ...           ...
# SG-5-E-R-D-V_Uncertainty -0.082921   -0.040224 -0.024144     -0.021943
# SG-5-E-R-E-D_Uncertainty -0.039044   -0.153883 -0.024107      0.127993
# SG-5-E-R-E-H_Uncertainty -0.058742   -0.169300 -0.011632      0.155611
# SG-5-E-R-E-V_Uncertainty -0.096663   -0.167117 -0.042659      0.167331
# SG-8-E-R-A-D_Uncertainty -0.059312   -0.116478  0.065083      0.213798
# SG-8-E-R-A-H_Uncertainty -0.057140   -0.110073  0.039544      0.201769
# SG-8-E-R-A-V_Uncertainty -0.075908   -0.145357  0.053908      0.199465
# SG-8-E-R-B-D_Uncertainty -0.062213   -0.133118  0.073511      0.196685
# SG-8-E-R-B-H_Uncertainty -0.024635   -0.075499 -0.009526      0.142354
# SG-8-E-R-B-V_Uncertainty -0.065140   -0.139461  0.087779      0.207087
# SG-8-W-R-A-D_Uncertainty -0.064539   -0.117211  0.022108      0.184297
# SG-8-W-R-A-H_Uncertainty -0.031195   -0.069269 -0.012679      0.143741
# SG-8-W-R-A-V_Uncertainty -0.054694   -0.103864  0.037191      0.173922
# SG-8-W-R-B-D_Uncertainty -0.075869   -0.112267  0.073456      0.150318
# SG-8-W-R-B-H_Uncertainty -0.054725   -0.117061  0.016703      0.164284
# SG-8-W-R-B-V_Uncertainty -0.084825   -0.153465  0.065962      0.225971
# SG-9-E-R-A-D_Uncertainty -0.078568   -0.049142 -0.071217     -0.002802
# SG-9-E-R-A-H_Uncertainty -0.012628   -0.052398  0.008744      0.140034
# SG-9-E-R-A-V_Uncertainty -0.039460   -0.072789  0.012626      0.170724
# SG-9-E-R-B-D_Uncertainty  0.025739   -0.009457  0.032466      0.119093
# SG-9-E-R-B-H_Uncertainty -0.027319   -0.065561 -0.005475      0.166358
# SG-9-E-R-B-V_Uncertainty  0.014824   -0.028257  0.066845      0.154757
# T-10-E-TW-SF_Uncertainty -0.049783   -0.078462  0.045003      0.088694
# T-10-E-TW-WB_Uncertainty -0.080170   -0.117237  0.049788      0.075684
# T-9-E-TW-SF_Uncertainty  -0.069746   -0.139241  0.008580      0.097314
# T-9-E-TW-WB_Uncertainty  -0.036117   -0.064626  0.054604      0.070984
# Weekday                   1.000000    0.779763  0.066180     -0.176364
# is_Weekend                0.779763    1.000000 -0.018335     -0.248800
# Hour                      0.066180   -0.018335  1.000000      0.006344
# is_Rush_Hour             -0.176364   -0.248800  0.006344      1.000000
#
# [268 rows x 268 columns]

# %%
# Plot again - resample by hours
df_hour = df.resample('H').mean()

# %%
plt.figure(dpi=200)

# iterate colour
x = np.linspace(0, 1, 13)
cmap = plt.get_cmap('tab20')
cmap_weekend = plt.get_cmap('inferno')
i = 0

for day in list(df_hour.index.day.unique()):
    df = df_hour[df_hour.index.day == day]
    if df['is_Weekend'].median() == 1:
        color = cmap_weekend(x[0])
    else:
        color = cmap(x[i])
    
    plt.plot(df.index.hour, df['SG-3-E-R-A-D_Average'], '-o', color=color, label=day, alpha=0.7)
    i += 1
    
plt.legend(ncol=3)
title = 'SG 3 Variation per Day'
plt.title(title)
plt.xlabel('Hour')
plt.ylabel('Strain (ue)')
plt.xlim([0, 23])
plt.savefig(title)

# %%
# save df with features as df_feature.p
pd.to_pickle(df, 'df-features.p')
